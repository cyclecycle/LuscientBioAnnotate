# %% [markdown]
# # Automatically annotate life science literature with named entities
#
# ### Objectives:
#     Map terms to classes:
#         chemical
#         biomolecule
#         drug
#         process
#         anatomy
#         species
#         disease
#         method
#
# ### Sources:
#     1. Pubtator
#     2. DBpedia, DBpedia spotlight
#     3. BIO2RDF

# %%
# get pubtator annotations
import requests
import json
import pandas as pd
import numpy as np
from IPython.display import display
base = 'https://www.ncbi.nlm.nih.gov/CBBresearch/Lu/Demo/RESTful/tmTool.cgi/BioConcept'
retmode = 'json'
pmid = '29969095'
url = '{0}/{1}/{2}' .format(base, pmid, retmode)
r = requests.get(url).text
j = json.loads(r)
text = j[0]['text']
print(text)
pbt_ann = []
pbt2class = {
    'gene': 'biomolecule',
    'species': 'species',
    'chemical': 'chemical',
    'disease': 'disease',
}
for a in j[0]['denotations']:
    pbt_class = a['obj'].split(':')[0].lower()
    try:
        mapped_class = pbt2class[pbt_class]
        pass
    except:
        print('Unmapped class: ', pbt_class)
        mapped_class = np.nan
    strt = a['span']['begin']
    end = a['span']['end']
    s = text[strt:end]
    pbt_ann.append((s, pbt_class, mapped_class))
pbt = pd.DataFrame(list(pbt_ann), columns=['term', 'pubtator_class', 'pubtator_mapped_class']).set_index('term')
pbt.drop_duplicates(inplace=True)
display(pbt)
# Out:
# Neurogenic decisions require a cell cycle independent function of the CDC25B phosphatase. A fundamental issue in developmental biology and in organ homeostasis is understanding the molecular mechanisms governing the balance between stem cell maintenance and differentiation into a specific lineage. Accumulating data suggest that cell cycle dynamics play a major role in the regulation of this balance. Here we show that the G2/M cell cycle regulator CDC25B phosphatase is required in mammals to finely tune neuronal production in the neural tube. We show that in chick neural progenitors, CDC25B activity favors fast nuclei departure from the apical surface in early G1, stimulates neurogenic divisions and promotes neuronal differentiation. We design a mathematical model showing that within a limited period of time, cell cycle length modifications cannot account for changes in the ratio of the mode of division. Using a CDC25B point mutation that cannot interact with CDK, we show that part of CDC25B activity is independent of its action on the cell cycle.
#                      pubtator_class pubtator_mapped_class
# term
# Neurogenic decisions        disease               disease
# CDC25B                         gene           biomolecule
# chick                       species               species

# %%
import spotlight

base = 'https://api.dbpedia-spotlight.org/en/annotate'
annotations = spotlight.annotate(base, text, confidence=0.4, support=5)
annotations
# Out:
# [{'URI': 'http://dbpedia.org/resource/Cell_cycle',
#   'support': 1839,
#   'types': '',
#   'surfaceForm': 'cell cycle',
#   'offset': 31,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 6.106436594423217e-20},
#  {'URI': 'http://dbpedia.org/resource/Subroutine',
#   'support': 3978,
#   'types': '',
#   'surfaceForm': 'function',
#   'offset': 54,
#   'similarityScore': 0.893844864875603,
#   'percentageOfSecondRank': 0.11365424768746649},
#  {'URI': 'http://dbpedia.org/resource/CDC25B',
#   'support': 12,
#   'types': '',
#   'surfaceForm': 'CDC25B',
#   'offset': 70,
#   'similarityScore': 0.9999999999889724,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Phosphatase',
#   'support': 494,
#   'types': '',
#   'surfaceForm': 'phosphatase',
#   'offset': 77,
#   'similarityScore': 0.9999999999998863,
#   'percentageOfSecondRank': 1.580676278011721e-13},
#  {'URI': 'http://dbpedia.org/resource/Molecular_biology',
#   'support': 2760,
#   'types': '',
#   'surfaceForm': 'biology',
#   'offset': 127,
#   'similarityScore': 0.9511311952810937,
#   'percentageOfSecondRank': 0.05129037910664583},
#  {'URI': 'http://dbpedia.org/resource/Homeostasis',
#   'support': 1376,
#   'types': '',
#   'surfaceForm': 'homeostasis',
#   'offset': 148,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Stem_cell',
#   'support': 3725,
#   'types': 'Wikidata:Q4936952,DBpedia:AnatomicalStructure',
#   'surfaceForm': 'stem cell',
#   'offset': 232,
#   'similarityScore': 0.999999999733177,
#   'percentageOfSecondRank': 1.9998238002377074e-10},
#  {'URI': 'http://dbpedia.org/resource/Cellular_differentiation',
#   'support': 1743,
#   'types': '',
#   'surfaceForm': 'differentiation',
#   'offset': 258,
#   'similarityScore': 0.999999917412996,
#   'percentageOfSecondRank': 8.258699948942553e-08},
#  {'URI': 'http://dbpedia.org/resource/Cell_cycle',
#   'support': 1839,
#   'types': '',
#   'surfaceForm': 'cell cycle',
#   'offset': 330,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 6.106436594423217e-20},
#  {'URI': 'http://dbpedia.org/resource/Cell_cycle_checkpoint',
#   'support': 131,
#   'types': '',
#   'surfaceForm': 'G2/M',
#   'offset': 425,
#   'similarityScore': 0.9999690875416459,
#   'percentageOfSecondRank': 3.0913414013229976e-05},
#  {'URI': 'http://dbpedia.org/resource/Cell_cycle',
#   'support': 1839,
#   'types': '',
#   'surfaceForm': 'cell cycle',
#   'offset': 430,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 6.106436594423217e-20},
#  {'URI': 'http://dbpedia.org/resource/CDC25B',
#   'support': 12,
#   'types': '',
#   'surfaceForm': 'CDC25B',
#   'offset': 451,
#   'similarityScore': 0.9999999999889724,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Phosphatase',
#   'support': 494,
#   'types': '',
#   'surfaceForm': 'phosphatase',
#   'offset': 458,
#   'similarityScore': 0.9999999999998863,
#   'percentageOfSecondRank': 1.580676278011721e-13},
#  {'URI': 'http://dbpedia.org/resource/Neural_tube',
#   'support': 475,
#   'types': 'Wikidata:Q4936952,DBpedia:Embryology,DBpedia:AnatomicalStructure',
#   'surfaceForm': 'neural tube',
#   'offset': 535,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/CDC25B',
#   'support': 12,
#   'types': '',
#   'surfaceForm': 'CDC25B',
#   'offset': 590,
#   'similarityScore': 0.9999999999889724,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Cell_nucleus',
#   'support': 3124,
#   'types': '',
#   'surfaceForm': 'nuclei',
#   'offset': 618,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 4.7380372320808e-14},
#  {'URI': 'http://dbpedia.org/resource/Cell_membrane',
#   'support': 4270,
#   'types': '',
#   'surfaceForm': 'apical surface',
#   'offset': 644,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/G1_phase',
#   'support': 315,
#   'types': '',
#   'surfaceForm': 'G1',
#   'offset': 668,
#   'similarityScore': 0.99999999790316,
#   'percentageOfSecondRank': 2.096789471884939e-09},
#  {'URI': 'http://dbpedia.org/resource/Neurogenesis',
#   'support': 684,
#   'types': '',
#   'surfaceForm': 'neurogenic',
#   'offset': 683,
#   'similarityScore': 0.9998758625744072,
#   'percentageOfSecondRank': 0.00012415283739425578},
#  {'URI': 'http://dbpedia.org/resource/Cellular_differentiation',
#   'support': 1743,
#   'types': '',
#   'surfaceForm': 'differentiation',
#   'offset': 726,
#   'similarityScore': 0.999999917412996,
#   'percentageOfSecondRank': 8.258699948942553e-08},
#  {'URI': 'http://dbpedia.org/resource/Mathematical_model',
#   'support': 1816,
#   'types': '',
#   'surfaceForm': 'mathematical model',
#   'offset': 755,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 3.0842626632049677e-22},
#  {'URI': 'http://dbpedia.org/resource/Cell_cycle',
#   'support': 1839,
#   'types': '',
#   'surfaceForm': 'cell cycle',
#   'offset': 820,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 6.106436594423217e-20},
#  {'URI': 'http://dbpedia.org/resource/CDC25B',
#   'support': 12,
#   'types': '',
#   'surfaceForm': 'CDC25B',
#   'offset': 925,
#   'similarityScore': 0.9999999999889724,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Point_mutation',
#   'support': 271,
#   'types': '',
#   'surfaceForm': 'point mutation',
#   'offset': 932,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Gene_regulatory_network',
#   'support': 194,
#   'types': '',
#   'surfaceForm': 'interact',
#   'offset': 959,
#   'similarityScore': 0.9999999983500629,
#   'percentageOfSecondRank': 1.558786960030408e-09},
#  {'URI': 'http://dbpedia.org/resource/Cyclin-dependent_kinase',
#   'support': 294,
#   'types': 'Wikidata:Q8047,Wikidata:Q206229,DBpedia:Enzyme,DBpedia:Biomolecule',
#   'surfaceForm': 'CDK',
#   'offset': 973,
#   'similarityScore': 0.9994089262537745,
#   'percentageOfSecondRank': 0.0005914233209732562},
#  {'URI': 'http://dbpedia.org/resource/CDC25B',
#   'support': 12,
#   'types': '',
#   'surfaceForm': 'CDC25B',
#   'offset': 999,
#   'similarityScore': 0.9999999999889724,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Cell_cycle',
#   'support': 1839,
#   'types': '',
#   'surfaceForm': 'cell cycle',
#   'offset': 1051,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 6.106436594423217e-20}]

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
sparql = SPARQLWrapper('http://dbpedia.org/sparql')
sparql.setReturnFormat(JSON)

def check_dbp_redirect(uri):
    q = 'SELECT * WHERE {{ {0} <http://dbpedia.org/ontology/wikiPageRedirects> ?redirect}}'.format(uri)
    sparql.setQuery(q)
    results = sparql.query().convert()
    try:
        uri = '<{0}>' .format(results['results']['bindings'][0]['redirect']['value'])
    except:
        pass
    return uri

dbp2class = {  # Map dbpedia types to our standard classes
    'biomolecule': 'biomolecule',
    'protein': 'biomolecule',
    'species': 'species',
    'eukaryote': 'species',
    'animal': 'species',
    'mammal': 'species',
    'disease': 'disease',
    'anatomicalstructure': 'anatomy'
}

dbp_ann = {}
for a in annotations:
    term = a['surfaceForm']
    types = a['types'].lower().replace('dbpedia:', '').split(',')
    uri = '<{0}>' .format(a['URI'])
    uri = check_dbp_redirect(uri)
    types = [t for t in types if t in dbp2class.keys()]
    classes = [dbp2class[t] for t in types]
    dbp_ann[term] = {
        'dbpedia_types': a['types'],
        'dbpedia_mapped_classes': classes,
        'dbpedia_resource': uri,   
    }

dbp = pd.DataFrame(dbp_ann).transpose()
dbp
# Out:
#                    dbpedia_mapped_classes  \
# cell cycle                             []
# function                               []
# CDC25B                                 []
# phosphatase                            []
# biology                                []
# homeostasis                            []
# stem cell                       [anatomy]
# differentiation                        []
# G2/M                                   []
# neural tube                     [anatomy]
# nuclei                                 []
# apical surface                         []
# G1                                     []
# neurogenic                             []
# mathematical model                     []
# point mutation                         []
# interact                               []
# CDK                         [biomolecule]
#
#                                                      dbpedia_resource  \
# cell cycle                   <http://dbpedia.org/resource/Cell_cycle>
# function                     <http://dbpedia.org/resource/Subroutine>
# CDC25B                           <http://dbpedia.org/resource/CDC25B>
# phosphatase                 <http://dbpedia.org/resource/Phosphatase>
# biology               <http://dbpedia.org/resource/Molecular_biology>
# homeostasis                 <http://dbpedia.org/resource/Homeostasis>
# stem cell                     <http://dbpedia.org/resource/Stem_cell>
# differentiation     <http://dbpedia.org/resource/Cellular_differen...
# G2/M                <http://dbpedia.org/resource/Cell_cycle_checkp...
# neural tube                 <http://dbpedia.org/resource/Neural_tube>
# nuclei                     <http://dbpedia.org/resource/Cell_nucleus>
# apical surface            <http://dbpedia.org/resource/Cell_membrane>
# G1                             <http://dbpedia.org/resource/G1_phase>
# neurogenic                 <http://dbpedia.org/resource/Neurogenesis>
# mathematical model   <http://dbpedia.org/resource/Mathematical_model>
# point mutation           <http://dbpedia.org/resource/Point_mutation>
# interact            <http://dbpedia.org/resource/Gene_regulatory_n...
# CDK                 <http://dbpedia.org/resource/Cyclin-dependent_...
#
#                                                         dbpedia_types
# cell cycle
# function
# CDC25B
# phosphatase
# biology
# homeostasis
# stem cell               Wikidata:Q4936952,DBpedia:AnatomicalStructure
# differentiation
# G2/M
# neural tube         Wikidata:Q4936952,DBpedia:Embryology,DBpedia:A...
# nuclei
# apical surface
# G1
# neurogenic
# mathematical model
# point mutation
# interact
# CDK                 Wikidata:Q8047,Wikidata:Q206229,DBpedia:Enzyme...

# %%
# create lists of dbpedia URIs to assign dbpedia annotations without classes
class_props = {
    'method': [
        'rdf:type yago:WikicatBiologicalTechniquesAndTools',
        'rdf:type yago:WikicatLaboratoryTechniques',
        'rdf:type yago:WikicatMolecularBiologyTechniques',
        'rdf:type yago:Method105660268',
        'rdf:type yago:Invention105633385',
        'rdf:type yago:Technique105665146',
        'rdf:type yago:WikicatBiochemistryMethods',
        'rdf:type yago:WikicatProteinMethods',
        'dct:subject dbc:Laboratory_techniques',
        'dct:subject dbc:Molecular_biology_techniques',
        'dct:subject dbc:Protein_methods',
    ],
    'pathway_process': [
        'dct:subject <http://dbpedia.org/resource/Category:Cellular_processes>',
        'rdf:type yago:WikicatCellularProcesses',
    ]
}

base = '''
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX dct: <http://purl.org/dc/terms/subject>
    PREFIX yago: <http://dbpedia.org/class/yago/>
    PREFIX dbc: <http://dbpedia.org/resource/>
    SELECT ?resource WHERE {{
        # ?resource {0}
    }}
'''

class_URIs = {}
for c, pr in class_props.items():
    uris = []
    for p in pr:
        q = base.format(p)
        sparql.setQuery(q)
        r = sparql.query().convert()
        uris += ['<{0}>' .format(d['resource']['value']) for d in r['results']['bindings']]
    class_URIs[c] = uris

for c, ur in class_URIs.items():
    print(len(ur), c)
# Out:
# 9744 method
# 65 pathway_process

# %%
# use other dbpedia data to assign classes
classless = dbp.loc[dbp['dbpedia_classes'].isnull()]['dbpedia_resource'].values

for c, ur in class_URIs.items():
    m = map(lambda x: x if x in ur else False, classless)
#     f = filter(lambda x: x, m)
    for uri in f:
        idx = dbp.loc[dbp['dbpedia_resource']==uri].index[0]
        dbp.loc[idx, 'dbpedia_mapped_classes'] = c

display(dbp)
# Out:
#                    dbpedia_classes  \
# cell cycle                      []
# function                        []
# CDC25B                          []
# phosphatase                     []
# biology                         []
# homeostasis                     []
# stem cell                [anatomy]
# differentiation                 []
# G2/M                            []
# neural tube              [anatomy]
# nuclei                          []
# apical surface                  []
# G1                              []
# neurogenic                      []
# mathematical model              []
# point mutation                  []
# interact                        []
# CDK                  [biomolecule]
#
#                                                      dbpedia_resource  \
# cell cycle                   <http://dbpedia.org/resource/Cell_cycle>
# function                     <http://dbpedia.org/resource/Subroutine>
# CDC25B                           <http://dbpedia.org/resource/CDC25B>
# phosphatase                 <http://dbpedia.org/resource/Phosphatase>
# biology               <http://dbpedia.org/resource/Molecular_biology>
# homeostasis                 <http://dbpedia.org/resource/Homeostasis>
# stem cell                     <http://dbpedia.org/resource/Stem_cell>
# differentiation     <http://dbpedia.org/resource/Cellular_differen...
# G2/M                <http://dbpedia.org/resource/Cell_cycle_checkp...
# neural tube                 <http://dbpedia.org/resource/Neural_tube>
# nuclei                     <http://dbpedia.org/resource/Cell_nucleus>
# apical surface            <http://dbpedia.org/resource/Cell_membrane>
# G1                             <http://dbpedia.org/resource/G1_phase>
# neurogenic                 <http://dbpedia.org/resource/Neurogenesis>
# mathematical model   <http://dbpedia.org/resource/Mathematical_model>
# point mutation           <http://dbpedia.org/resource/Point_mutation>
# interact            <http://dbpedia.org/resource/Gene_regulatory_n...
# CDK                 <http://dbpedia.org/resource/Cyclin-dependent_...
#
#                                                         dbpedia_types
# cell cycle
# function
# CDC25B
# phosphatase
# biology
# homeostasis
# stem cell               Wikidata:Q4936952,DBpedia:AnatomicalStructure
# differentiation
# G2/M
# neural tube         Wikidata:Q4936952,DBpedia:Embryology,DBpedia:A...
# nuclei
# apical surface
# G1
# neurogenic
# mathematical model
# point mutation
# interact
# CDK                 Wikidata:Q8047,Wikidata:Q206229,DBpedia:Enzyme...

# %%
# join dfs
df = pbt.join(dbp, how='outer')

# %%
# bio2rdf
sparql = SPARQLWrapper('http://pubmed.bio2rdf.org/sparql')
sparql.setReturnFormat(JSON)

base = '''
SELECT DISTINCT ?concept ?type WHERE {{
# ?concept dcterms:title "{0}"@en . 
# ?concept rdf:type ?type .
}}
'''

bio2rdf = {}
for t in df.index:
    q = base.format(t)
    sparql.setQuery(q)
    results = sparql.query().convert()
    if not results:
        continue
    bio2rdf[t] = {
        'bio2rdf_uris': [r['concept']['value'] for r in results['results']['bindings']],
        'bio2rdf_classes': [r['type']['value'] for r in results['results']['bindings']],
    }
bio2rdf = pd.DataFrame(bio2rdf).transpose()
display(bio2rdf)
# Out:
#                                                           bio2rdf_class  \
# CDC25B                [http://bio2rdf.org/hgnc.symbol_vocabulary:Res...
# CDK                                                                  []
# G1                    [http://bio2rdf.org/clinicaltrials_vocabulary:...
# G2/M                                                                 []
# Neurogenic decisions                                                 []
# apical surface                                                       []
# biology                                                              []
# cell cycle            [http://www.w3.org/2002/07/owl#Class, http://b...
# chick                                                                []
# differentiation                                                      []
# function              [http://www.w3.org/2002/07/owl#Class, http://b...
# homeostasis                                                          []
# interact                                                             []
# mathematical model                                                   []
# neural tube                                                          []
# neurogenic                                                           []
# nuclei                                                               []
# phosphatase                                                          []
# point mutation                                                       []
# stem cell             [http://bio2rdf.org/clinicaltrials_vocabulary:...
#
#                                                             bio2rdf_uri
# CDC25B                [http://bio2rdf.org/hgnc.symbol:CDC25B, http:/...
# CDK                                                                  []
# G1                    [http://bio2rdf.org/clinicaltrials_resource:NC...
# G2/M                                                                 []
# Neurogenic decisions                                                 []
# apical surface                                                       []
# biology                                                              []
# cell cycle            [http://bio2rdf.org/go:0007049, http://bio2rdf...
# chick                                                                []
# differentiation                                                      []
# function              [http://bio2rdf.org/goa_resource:c1c425268e683...
# homeostasis                                                          []
# interact                                                             []
# mathematical model                                                   []
# neural tube                                                          []
# neurogenic                                                           []
# nuclei                                                               []
# phosphatase                                                          []
# point mutation                                                       []
# stem cell             [http://bio2rdf.org/clinicaltrials_resource:6c...

# %%
df = df.join(goa)
display(df)
# Out:
#                      pubtator_class pubtator_mapped_class  \
# CDC25B                         gene           biomolecule
# CDK                             NaN                   NaN
# G1                              NaN                   NaN
# G2/M                            NaN                   NaN
# Neurogenic decisions        disease               disease
# apical surface                  NaN                   NaN
# biology                         NaN                   NaN
# cell cycle                      NaN                   NaN
# chick                       species               species
# differentiation                 NaN                   NaN
# function                        NaN                   NaN
# homeostasis                     NaN                   NaN
# interact                        NaN                   NaN
# mathematical model              NaN                   NaN
# neural tube                     NaN                   NaN
# neurogenic                      NaN                   NaN
# nuclei                          NaN                   NaN
# phosphatase                     NaN                   NaN
# point mutation                  NaN                   NaN
# stem cell                       NaN                   NaN
#
#                      dbpedia_mapped_classes  \
# CDC25B                                   []
# CDK                           [biomolecule]
# G1                                       []
# G2/M                                     []
# Neurogenic decisions                    NaN
# apical surface                           []
# biology                                  []
# cell cycle                               []
# chick                                   NaN
# differentiation                          []
# function                                 []
# homeostasis                              []
# interact                                 []
# mathematical model                       []
# neural tube                       [anatomy]
# neurogenic                               []
# nuclei                                   []
# phosphatase                              []
# point mutation                           []
# stem cell                         [anatomy]
#
#                                                        dbpedia_resource  \
# CDC25B                             <http://dbpedia.org/resource/CDC25B>
# CDK                   <http://dbpedia.org/resource/Cyclin-dependent_...
# G1                               <http://dbpedia.org/resource/G1_phase>
# G2/M                  <http://dbpedia.org/resource/Cell_cycle_checkp...
# Neurogenic decisions                                                NaN
# apical surface              <http://dbpedia.org/resource/Cell_membrane>
# biology                 <http://dbpedia.org/resource/Molecular_biology>
# cell cycle                     <http://dbpedia.org/resource/Cell_cycle>
# chick                                                               NaN
# differentiation       <http://dbpedia.org/resource/Cellular_differen...
# function                       <http://dbpedia.org/resource/Subroutine>
# homeostasis                   <http://dbpedia.org/resource/Homeostasis>
# interact              <http://dbpedia.org/resource/Gene_regulatory_n...
# mathematical model     <http://dbpedia.org/resource/Mathematical_model>
# neural tube                   <http://dbpedia.org/resource/Neural_tube>
# neurogenic                   <http://dbpedia.org/resource/Neurogenesis>
# nuclei                       <http://dbpedia.org/resource/Cell_nucleus>
# phosphatase                   <http://dbpedia.org/resource/Phosphatase>
# point mutation             <http://dbpedia.org/resource/Point_mutation>
# stem cell                       <http://dbpedia.org/resource/Stem_cell>
#
#                                                           dbpedia_types  \
# CDC25B
# CDK                   Wikidata:Q8047,Wikidata:Q206229,DBpedia:Enzyme...
# G1
# G2/M
# Neurogenic decisions                                                NaN
# apical surface
# biology
# cell cycle
# chick                                                               NaN
# differentiation
# function
# homeostasis
# interact
# mathematical model
# neural tube           Wikidata:Q4936952,DBpedia:Embryology,DBpedia:A...
# neurogenic
# nuclei
# phosphatase
# point mutation
# stem cell                 Wikidata:Q4936952,DBpedia:AnatomicalStructure
#
#                                goa_class                        goa_uri
# CDC25B                               NaN                            NaN
# CDK                                  NaN                            NaN
# G1                                   NaN                            NaN
# G2/M                                 NaN                            NaN
# Neurogenic decisions                 NaN                            NaN
# apical surface                       NaN                            NaN
# biology                              NaN                            NaN
# cell cycle            biological_process  http://bio2rdf.org/go:0007049
# chick                                NaN                            NaN
# differentiation                      NaN                            NaN
# function                             NaN                            NaN
# homeostasis                          NaN                            NaN
# interact                             NaN                            NaN
# mathematical model                   NaN                            NaN
# neural tube                          NaN                            NaN
# neurogenic                           NaN                            NaN
# nuclei                               NaN                            NaN
# phosphatase                          NaN                            NaN
# point mutation                       NaN                            NaN
# stem cell                            NaN                            NaN

# %%
# get meta data for terms with classes
df = df.loc[
    (df['pubtator_class'].notnull()) |
    (df['dbpedia_class'].notnull()) |
    (df['goa_class'].notnull())
]
display(df)
# get wikipedia info
